# %%
import matplotlib.pyplot as plt
from numpy import set_printoptions
from pandas import read_csv

# %%
filename = 'C:\\Users\\Gururajan\\data_science_AI_and_ML_program\\data_analysis\\daily_retail_price_Onion-upto_apr_2015.csv'
names = ['Date','Centre_Name','Commodity_Name','Price']
data = read_csv(filename,names = names)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-2d34965a437f> in <module>
#       1 filename = 'C:\\Users\\Gururajan\\data_science_AI_and_ML_program\\data_analysis\\daily_retail_price_Onion-upto_apr_2015.csv'
#       2 names = ['Date','Centre_Name','Commodity_Name','Price']
# ----> 3 data = read_csv(filename,names = names)
#
# ...

# %%
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-dbd883db58b7> in <module>
# ----> 1 print(data)
#
# NameError: name 'data' is not defined

# %%
print(data.shape)
# Out:
# (127911, 4)

# %%
print(data.head(15))
# Out:
#         Date   Centre_Name Commodity_Name  Price
# 0   25-11-97         DELHI          Onion    8.0
# 1   25-11-97        SHIMLA          Onion    7.0
# 2   25-11-97       LUCKNOW          Onion    5.0
# 3   25-11-97     AHMEDABAD          Onion    6.0
# 4   25-11-97        BHOPAL          Onion    8.0
# 5   25-11-97        MUMBAI          Onion    7.0
# 6   25-11-97        JAIPUR          Onion    6.0
# 7   25-11-97         PATNA          Onion    NaN
# 8   25-11-97  BHUBANESHWAR          Onion    9.0
# 9   25-11-97       KOLKATA          Onion   11.0
# 10  25-11-97      GUWAHATI          Onion    8.0
# 11  25-11-97      SHILLONG          Onion    9.0
# 12  25-11-97        AIZWAL          Onion    9.0
# 13  25-11-97      AGARTALA          Onion    9.0
# 14  25-11-97     BENGALURU          Onion    6.0

# %%
minprice = data['Price'].min()
print(minprice)
# Out:
# 2.0

# %%
print(data[data.Price == int(minprice)])
# Out:
#            Date Centre_Name Commodity_Name  Price
# 9768   09-02-00   BENGALURU          Onion    2.0
# 10328  27-03-00     CHENNAI          Onion    2.0
# 10580  18-04-00     CHENNAI          Onion    2.0
# 10598  19-04-00     CHENNAI          Onion    2.0
# 11072  30-05-00      BHOPAL          Onion    2.0
# ...         ...         ...            ...    ...
# 37224  26-04-06      BHOPAL          Onion    2.0
# 37242  27-04-06      BHOPAL          Onion    2.0
# 37260  28-04-06      BHOPAL          Onion    2.0
# 37278  01-05-06      BHOPAL          Onion    2.0
# 37296  02-05-06      BHOPAL          Onion    2.0
#
# [92 rows x 4 columns]

# %%
print(data['Price'].max())
# Out:
# 100.0

# %%
maxprice = data['Price'].max()

# %%
print(data[data.Price == int(maxprice)])
# Out:
#             Date Centre_Name Commodity_Name  Price
# 105648  28-10-13      AIZWAL          Onion  100.0
# 105933  04-11-13      AIZWAL          Onion  100.0
# 105990  05-11-13      AIZWAL          Onion  100.0
# 106047  06-11-13      AIZWAL          Onion  100.0
# 106104  07-11-13      AIZWAL          Onion  100.0
# 106161  08-11-13      AIZWAL          Onion  100.0
# 106218  11-11-13      AIZWAL          Onion  100.0
# 106275  12-11-13      AIZWAL          Onion  100.0
# 106332  13-11-13      AIZWAL          Onion  100.0
# 106446  18-11-13      AIZWAL          Onion  100.0
# 106560  20-11-13      AIZWAL          Onion  100.0
# 106617  21-11-13      AIZWAL          Onion  100.0
# 106674  22-11-13      AIZWAL          Onion  100.0
# 106845  27-11-13      AIZWAL          Onion  100.0
# 106902  28-11-13      AIZWAL          Onion  100.0
# 106959  29-11-13      AIZWAL          Onion  100.0
# 107016  02-12-13      AIZWAL          Onion  100.0
# ...

# %%
print(len(data[data.Price == int(maxprice)]))
# Out:
# 18

# %%
print(len(data[data.Price == int(minprice)]))
# Out:
# 92

# %%
print(data.describe())
# Out:
#                Price
# count  115991.000000
# mean       16.224441
# std        11.276851
# min         2.000000
# 25%         9.000000
# 50%        13.000000
# 75%        20.000000
# max       100.000000

# %%
data.describe()
# Out:
#                Price
# count  115991.000000
# mean       16.224441
# std        11.276851
# min         2.000000
# 25%         9.000000
# 50%        13.000000
# 75%        20.000000
# max       100.000000

# %%
data.std()
# Out:
# Price    11.276851
# dtype: float64

# %%
data.shape
# Out:
# (127911, 4)

# %%
data.skew
# Out:
# <bound method DataFrame.skew of             Date      Centre_Name Commodity_Name  Price
# 0       25-11-97            DELHI          Onion    8.0
# 1       25-11-97           SHIMLA          Onion    7.0
# 2       25-11-97          LUCKNOW          Onion    5.0
# 3       25-11-97        AHMEDABAD          Onion    6.0
# 4       25-11-97           BHOPAL          Onion    8.0
# ...          ...              ...            ...    ...
# 127906  28-04-15         DINDIGUL          Onion   18.0
# 127907  28-04-15  THIRUCHIRAPALLI          Onion   18.0
# 127908  28-04-15       COIMBATORE          Onion   18.0
# 127909  28-04-15      TIRUNELVELI          Onion   18.0
# 127910  28-04-15        HYDERABAD          Onion   22.0
#
# [127911 rows x 4 columns]>

# %%
data[['Price']].head()
# Out:
#    Price
# 0    8.0
# 1    7.0
# 2    5.0
# 3    6.0
# 4    8.0

# %%
data[['Price']].max()
# Out:
# Price    100.0
# dtype: float64

# %%
data[['Price']].std()
# Out:
# Price    11.276851
# dtype: float64

# %%
data[['Price']].describe()
# Out:
#                Price
# count  115991.000000
# mean       16.224441
# std        11.276851
# min         2.000000
# 25%         9.000000
# 50%        13.000000
# 75%        20.000000
# max       100.000000

# %%
print(len(data[data.Price < 5]))
# Out:
# 4160

# %%
data[['Price']]
# Out:
#         Price
# 0         8.0
# 1         7.0
# 2         5.0
# 3         6.0
# 4         8.0
# ...       ...
# 127906   18.0
# 127907   18.0
# 127908   18.0
# 127909   18.0
# 127910   22.0
#
# [127911 rows x 1 columns]

# %%
data[['Price']].std()
# Out:
# Price    11.276851
# dtype: float64

# %%
data.drop(["Date"], axis = 1)
# Out:
#             Centre_Name Commodity_Name  Price
# 0                 DELHI          Onion    8.0
# 1                SHIMLA          Onion    7.0
# 2               LUCKNOW          Onion    5.0
# 3             AHMEDABAD          Onion    6.0
# 4                BHOPAL          Onion    8.0
# ...                 ...            ...    ...
# 127906         DINDIGUL          Onion   18.0
# 127907  THIRUCHIRAPALLI          Onion   18.0
# 127908       COIMBATORE          Onion   18.0
# 127909      TIRUNELVELI          Onion   18.0
# 127910        HYDERABAD          Onion   22.0
#
# [127911 rows x 3 columns]

# %%
data['Price']
# Out:
# 0          8.0
# 1          7.0
# 2          5.0
# 3          6.0
# 4          8.0
#           ...
# 127906    18.0
# 127907    18.0
# 127908    18.0
# 127909    18.0
# 127910    22.0
# Name: Price, Length: 127911, dtype: float64

# %%
minprice = data[['Price']].min()
print(minprice)
len(data[data.Price == int(minprice)])
# Out:
# Price    2.0
# dtype: float64
# 92

# %%
data[data.Price == int(minprice)]
# Out:
#            Date Centre_Name Commodity_Name  Price
# 9768   09-02-00   BENGALURU          Onion    2.0
# 10328  27-03-00     CHENNAI          Onion    2.0
# 10580  18-04-00     CHENNAI          Onion    2.0
# 10598  19-04-00     CHENNAI          Onion    2.0
# 11072  30-05-00      BHOPAL          Onion    2.0
# ...         ...         ...            ...    ...
# 37224  26-04-06      BHOPAL          Onion    2.0
# 37242  27-04-06      BHOPAL          Onion    2.0
# 37260  28-04-06      BHOPAL          Onion    2.0
# 37278  01-05-06      BHOPAL          Onion    2.0
# 37296  02-05-06      BHOPAL          Onion    2.0
#
# [92 rows x 4 columns]

# %%
data[data.Price==int(maxprice)]
# Out:
#             Date Centre_Name Commodity_Name  Price
# 105648  28-10-13      AIZWAL          Onion  100.0
# 105933  04-11-13      AIZWAL          Onion  100.0
# 105990  05-11-13      AIZWAL          Onion  100.0
# 106047  06-11-13      AIZWAL          Onion  100.0
# 106104  07-11-13      AIZWAL          Onion  100.0
# 106161  08-11-13      AIZWAL          Onion  100.0
# 106218  11-11-13      AIZWAL          Onion  100.0
# 106275  12-11-13      AIZWAL          Onion  100.0
# 106332  13-11-13      AIZWAL          Onion  100.0
# 106446  18-11-13      AIZWAL          Onion  100.0
# 106560  20-11-13      AIZWAL          Onion  100.0
# 106617  21-11-13      AIZWAL          Onion  100.0
# 106674  22-11-13      AIZWAL          Onion  100.0
# 106845  27-11-13      AIZWAL          Onion  100.0
# 106902  28-11-13      AIZWAL          Onion  100.0
# 106959  29-11-13      AIZWAL          Onion  100.0
# 107016  02-12-13      AIZWAL          Onion  100.0
# ...

# %%
print(data[data.Price == int(minprice)].Centre_Name.unique())
print(data[data.Price == int(maxprice)].Centre_Name.unique())
# Out:
# ['BENGALURU' 'CHENNAI' 'BHOPAL']
# ['AIZWAL']

# %%
print(data[data.Price==int(maxprice)])
print(data[data.Price==int(minprice)])
# Out:
#             Date Centre_Name Commodity_Name  Price
# 105648  28-10-13      AIZWAL          Onion  100.0
# 105933  04-11-13      AIZWAL          Onion  100.0
# 105990  05-11-13      AIZWAL          Onion  100.0
# 106047  06-11-13      AIZWAL          Onion  100.0
# 106104  07-11-13      AIZWAL          Onion  100.0
# 106161  08-11-13      AIZWAL          Onion  100.0
# 106218  11-11-13      AIZWAL          Onion  100.0
# 106275  12-11-13      AIZWAL          Onion  100.0
# 106332  13-11-13      AIZWAL          Onion  100.0
# 106446  18-11-13      AIZWAL          Onion  100.0
# 106560  20-11-13      AIZWAL          Onion  100.0
# 106617  21-11-13      AIZWAL          Onion  100.0
# 106674  22-11-13      AIZWAL          Onion  100.0
# 106845  27-11-13      AIZWAL          Onion  100.0
# 106902  28-11-13      AIZWAL          Onion  100.0
# 106959  29-11-13      AIZWAL          Onion  100.0
# 107016  02-12-13      AIZWAL          Onion  100.0
# ...

# %%
print(len(data[data.Price==int(maxprice)]))
print(data[data.Price==int(maxprice)])
# Out:
# 18
#             Date Centre_Name Commodity_Name  Price
# 105648  28-10-13      AIZWAL          Onion  100.0
# 105933  04-11-13      AIZWAL          Onion  100.0
# 105990  05-11-13      AIZWAL          Onion  100.0
# 106047  06-11-13      AIZWAL          Onion  100.0
# 106104  07-11-13      AIZWAL          Onion  100.0
# 106161  08-11-13      AIZWAL          Onion  100.0
# 106218  11-11-13      AIZWAL          Onion  100.0
# 106275  12-11-13      AIZWAL          Onion  100.0
# 106332  13-11-13      AIZWAL          Onion  100.0
# 106446  18-11-13      AIZWAL          Onion  100.0
# 106560  20-11-13      AIZWAL          Onion  100.0
# 106617  21-11-13      AIZWAL          Onion  100.0
# 106674  22-11-13      AIZWAL          Onion  100.0
# 106845  27-11-13      AIZWAL          Onion  100.0
# 106902  28-11-13      AIZWAL          Onion  100.0
# 106959  29-11-13      AIZWAL          Onion  100.0
# 107016  02-12-13      AIZWAL          Onion  100.0
# ...

# %%
print(len(data[data.Price==int(minprice)]))
print(data[data.Price == int(maxprice)].Centre_Name.unique())
print(len(data[data.Price == int(maxprice)].Centre_Name.unique()))
# Out:
# 92
# ['AIZWAL']
# 1

# %%
print(data[data.Price == int(minprice)].Centre_Name.unique())
print(len(data[data.Price == int(minprice)].Centre_Name.unique()))
print(data[data.Price == int(maxprice)].Centre_Name.unique())
# Out:
# ['BENGALURU' 'CHENNAI' 'BHOPAL']
# 3
# ['AIZWAL']

# %%
#data[data.Price == int(minprice)].Centre_Name.unique()
df=list(data.groupby('Date'))#.Date.diff().dt.days.fillna(1).ne(1).cumsum()
#x[(today - x['Date']).dt.days == g.cumcount()].groupby(['ID']).size()

# %%
len(df)
# Out:
# 4292

# %%
df
# Out:
# [('01-01-01',            Date   Centre_Name Commodity_Name  Price
#   13714  01-01-01         DELHI          Onion    8.0
#   13715  01-01-01        SHIMLA          Onion    9.5
#   13716  01-01-01       LUCKNOW          Onion   10.0
#   13717  01-01-01     AHMEDABAD          Onion    7.0
#   13718  01-01-01        BHOPAL          Onion    6.0
#   13719  01-01-01        MUMBAI          Onion    9.0
#   13720  01-01-01        JAIPUR          Onion    8.0
#   13721  01-01-01         PATNA          Onion    NaN
#   13722  01-01-01  BHUBANESHWAR          Onion    9.0
#   13723  01-01-01       KOLKATA          Onion    9.0
#   13724  01-01-01      GUWAHATI          Onion   11.0
#   13725  01-01-01      SHILLONG          Onion    NaN
#   13726  01-01-01        AIZWAL          Onion    NaN
#   13727  01-01-01      AGARTALA          Onion   13.0
#   13728  01-01-01     BENGALURU          Onion    5.0
#   13729  01-01-01       T.PURAM          Onion   12.0
# ...

# %%
df=data.groupby(by='Date').apply(lambda x: x.sort_values(by='Date',ascending=False))#.iloc[[e for e in range(12) if e <len(x)]])

# %%
df
# Out:
#                     Date Centre_Name Commodity_Name  Price
# Date
# 01-01-01 13714  01-01-01       DELHI          Onion    8.0
#          13715  01-01-01      SHIMLA          Onion    9.5
#          13730  01-01-01     CHENNAI          Onion    8.0
#          13729  01-01-01     T.PURAM          Onion   12.0
#          13728  01-01-01   BENGALURU          Onion    5.0
# ...                  ...         ...            ...    ...
# 31-12-99 9273   31-12-99      MUMBAI          Onion    7.5
#          9272   31-12-99      BHOPAL          Onion    4.0
#          9271   31-12-99   AHMEDABAD          Onion    5.0
#          9270   31-12-99     LUCKNOW          Onion    5.0
#          9285   31-12-99   HYDERABAD          Onion    4.5
#
# [127911 rows x 4 columns]

# %%
df=list(data.groupby(by='Date'))

# %%
df[11]
# Out:
# ('01-01-99',           Date   Centre_Name Commodity_Name  Price
#  4823  01-01-99         DELHI          Onion  14.00
#  4824  01-01-99        SHIMLA          Onion  15.00
#  4825  01-01-99       LUCKNOW          Onion  15.00
#  4826  01-01-99     AHMEDABAD          Onion  10.00
#  4827  01-01-99        BHOPAL          Onion  10.00
#  4828  01-01-99        MUMBAI          Onion  10.75
#  4829  01-01-99        JAIPUR          Onion  15.00
#  4830  01-01-99         PATNA          Onion  18.00
#  4831  01-01-99  BHUBANESHWAR          Onion  16.00
#  4832  01-01-99       KOLKATA          Onion  12.00
#  4833  01-01-99      GUWAHATI          Onion  23.00
#  4834  01-01-99      SHILLONG          Onion  22.00
#  4835  01-01-99        AIZWAL          Onion    NaN
#  4836  01-01-99      AGARTALA          Onion  20.00
#  4837  01-01-99     BENGALURU          Onion   8.00
#  4838  01-01-99       T.PURAM          Onion  13.00
#  4839  01-01-99       CHENNAI          Onion  12.00
# ...

# %%
#data.iloc[:,0] # first column of data frame (first_name)
#data.iloc[:,1] # second column of data frame (last_name)
data.iloc[0:5,2:4] # last column of data frame (id)
# Out:
#              Price
# Centre_Name
# DELHI          8.0
# SHIMLA         7.0
# LUCKNOW        5.0
# AHMEDABAD      6.0
# BHOPAL         8.0

# %%
data.set_index("Date", inplace=True)
data
# Out:
#          Commodity_Name  Price
# Date
# 25-11-97          Onion    8.0
# 25-11-97          Onion    7.0
# 25-11-97          Onion    5.0
# 25-11-97          Onion    6.0
# 25-11-97          Onion    8.0
# ...                 ...    ...
# 28-04-15          Onion   18.0
# 28-04-15          Onion   18.0
# 28-04-15          Onion   18.0
# 28-04-15          Onion   18.0
# 28-04-15          Onion   22.0
#
# [127911 rows x 2 columns]

# %%
mim_price = data['Price'].min()
print("minimum price : ",mim_price)
mim_price_days = data['Date'].data['Price'] == mim_price]
day_diffrence = pd.Timedelta('1d')
consecutive_day = (mim_price_days.diff() == day_diffrence).cumsum().value_counts().to_list()
print('maximum consecutive days : ', consecutive_day[0])
# Out:
#   File "<ipython-input-172-34c744bfebee>", line 3
#     mim_price_days = data['Date'].data['Price'] == mim_price]
#                                                             ^
# SyntaxError: invalid syntax

# %%
data.iloc[-6:-1,2:4]
# Out:
#        Commodity_Name  Price
# 127905          Onion   19.0
# 127906          Onion   18.0
# 127907          Onion   18.0
# 127908          Onion   18.0
# 127909          Onion   18.0
