# %%
import pandas as pd                #for handling datasets
import statsmodels.api as sm       #for statistical modeling
import pylab as pl                 #for plotting
import numpy as np                 #for numerical computation
pd.set_option('display.max_rows',None)

# %%
filename = "train_university_admission_data.csv"
names = ['admit','gre','gpa','prestige']
dfTrain = pd.read_csv(filename, names=names)
#dfTest = pd.read_csv(filename, names=names)

# %%
#dfTrain = pd.read_csv("train_university_admission_data.csv")
#dfTest = pd.read_csv("test_university_admission_data.csv")

# %%
dfTrain.head()
# Out:
#    admit  gre   gpa prestige
# 0      0  380  3.61     good
# 1      1  660  3.67     good
# 2      1  800  4.00     best
# 3      1  640  3.19       ok
# 4      0  520  2.93       ok

# %%
dfTrain.shape
# Out:
# (300, 4)

# %%
dfTrain
# Out:
#      admit  gre   gpa  prestige
# 0        0  380  3.61      good
# 1        1  660  3.67      good
# 2        1  800  4.00      best
# 3        1  640  3.19        ok
# 4        0  520  2.93        ok
# 5        1  760  3.00  veryGood
# 6        1  560  2.98      best
# 7        0  400  3.08  veryGood
# 8        1  540  3.39      good
# 9        0  700  3.92  veryGood
# 10       0  800  4.00        ok
# 11       0  440  3.22      best
# 12       1  760  4.00      best
# 13       0  700  3.08  veryGood
# 14       1  700  4.00      best
# 15       0  480  3.44      good
# 16       0  780  3.87        ok
# 17       0  360  2.56      good
# 18       0  800  3.75  veryGood
# 19       1  540  3.81      best
# 20       0  500  3.17      good
# 21       1  660  3.63  veryGood
# 22       0  600  2.82        ok
# 23       0  680  3.19        ok
# 24       1  760  3.35  veryGood
# 25       1  800  3.66      best
# 26       1  620  3.61      best
# 27       1  520  3.74        ok
# 28       1  780  3.22  veryGood
# 29       0  520  3.29      best
# 30       0  540  3.78        ok
# 31       0  760  3.35      good
# 32       0  600  3.40      good
# 33       1  800  4.00      good
# 34       0  360  3.14      best
# 35       0  400  3.05  veryGood
# 36       0  580  3.25      best
# 37       0  520  2.90      good
# 38       1  500  3.13  veryGood
# 39       1  520  2.68      good
# 40       0  560  2.42  veryGood
# 41       1  580  3.32  veryGood
# 42       1  600  3.15  veryGood
# 43       0  500  3.31      good
# 44       0  700  2.94  veryGood
# 45       1  460  3.45      good
# 46       1  580  3.46  veryGood
# 47       0  500  2.97        ok
# 48       0  440  2.48        ok
# 49       0  400  3.35      good
# 50       0  640  3.86      good
# 51       0  440  3.13        ok
# 52       0  740  3.37        ok
# 53       1  680  3.27  veryGood
# 54       0  660  3.34      good
# 55       1  740  4.00      good
# 56       0  560  3.19      good
# 57       0  380  2.94      good
# 58       0  400  3.65  veryGood
# 59       0  600  2.82        ok
# 60       1  620  3.18  veryGood
# 61       0  560  3.32        ok
# 62       0  640  3.67      good
# 63       1  680  3.85      good
# 64       0  580  4.00      good
# 65       0  600  3.59  veryGood
# 66       0  740  3.62        ok
# 67       0  620  3.30      best
# 68       0  580  3.69      best
# 69       0  800  3.73      best
# 70       0  640  4.00      good
# 71       0  300  2.92        ok
# 72       0  480  3.39        ok
# 73       0  580  4.00  veryGood
# 74       0  720  3.45        ok
# 75       0  720  4.00      good
# 76       0  560  3.36      good
# 77       1  800  4.00      good
# 78       0  540  3.12      best
# 79       1  620  4.00      best
# 80       0  700  2.90        ok
# 81       0  620  3.07  veryGood
# 82       0  500  2.71  veryGood
# 83       0  380  2.91        ok
# 84       1  500  3.60      good
# 85       0  520  2.98  veryGood
# 86       0  600  3.32  veryGood
# 87       0  600  3.48  veryGood
# 88       0  700  3.28      best
# 89       1  660  4.00  veryGood
# 90       0  700  3.83  veryGood
# 91       1  720  3.64      best
# 92       0  800  3.90  veryGood
# 93       0  580  2.93  veryGood
# 94       1  660  3.44  veryGood
# 95       0  660  3.33  veryGood
# 96       0  640  3.52        ok
# 97       0  480  3.57  veryGood
# 98       0  700  2.88  veryGood
# 99       0  400  3.31      good
# 100      0  340  3.15      good
# 101      0  580  3.57      good
# 102      0  380  3.33        ok
# 103      0  540  3.94      good
# 104      1  660  3.95  veryGood
# 105      1  740  2.97  veryGood
# 106      1  700  3.56      best
# 107      0  480  3.13  veryGood
# 108      0  400  2.93      good
# 109      0  480  3.45  veryGood
# 110      0  680  3.08        ok
# 111      0  420  3.41        ok
# 112      0  360  3.00      good
# 113      0  600  3.22      best
# 114      0  720  3.84      good
# 115      0  620  3.99      good
# 116      1  440  3.45  veryGood
# 117      0  700  3.72  veryGood
# 118      1  800  3.70      best
# 119      0  340  2.92      good
# 120      1  520  3.74  veryGood
# 121      1  480  2.67  veryGood
# 122      0  520  2.85      good
# 123      0  500  2.98      good
# 124      0  720  3.88      good
# 125      0  540  3.38        ok
# 126      1  600  3.54      best
# 127      0  740  3.74        ok
# 128      0  540  3.19  veryGood
# 129      0  460  3.15        ok
# 130      1  620  3.17  veryGood
# 131      0  640  2.79  veryGood
# 132      0  580  3.40  veryGood
# 133      0  500  3.08      good
# 134      0  560  2.95  veryGood
# 135      0  500  3.57      good
# 136      0  560  3.33        ok
# 137      0  700  4.00      good
# 138      0  620  3.40  veryGood
# 139      1  600  3.58      best
# 140      0  640  3.93  veryGood
# 141      1  700  3.52        ok
# 142      0  620  3.94        ok
# 143      0  580  3.40      good
# 144      0  580  3.40        ok
# 145      0  380  3.43      good
# 146      0  480  3.40  veryGood
# 147      0  560  2.71      good
# 148      1  480  2.91      best
# 149      0  740  3.31      best
# 150      1  800  3.74      best
# 151      0  400  3.38  veryGood
# 152      1  640  3.94  veryGood
# 153      0  580  3.46      good
# 154      0  620  3.69      good
# 155      1  580  2.86        ok
# 156      0  560  2.52  veryGood
# 157      1  480  3.58      best
# 158      0  660  3.49  veryGood
# 159      0  700  3.82      good
# 160      0  600  3.13  veryGood
# 161      0  640  3.50  veryGood
# 162      1  700  3.56  veryGood
# 163      0  520  2.73  veryGood
# 164      0  580  3.30  veryGood
# 165      0  700  4.00      best
# 166      0  440  3.24        ok
# 167      0  720  3.77      good
# 168      0  500  4.00      good
# 169      0  600  3.62      good
# 170      0  400  3.51      good
# 171      0  540  2.81      good
# 172      0  680  3.48      good
# 173      1  800  3.43  veryGood
# 174      0  500  3.53        ok
# 175      1  620  3.37  veryGood
# 176      0  520  2.62  veryGood
# 177      1  620  3.23      good
# 178      0  620  3.33      good
# 179      0  300  3.01      good
# 180      0  620  3.78      good
# 181      0  500  3.88        ok
# 182      0  700  4.00  veryGood
# 183      1  540  3.84  veryGood
# 184      0  500  2.79        ok
# 185      0  800  3.60  veryGood
# 186      0  560  3.61      good
# 187      0  580  2.88  veryGood
# 188      0  560  3.07  veryGood
# 189      0  500  3.35  veryGood
# 190      1  640  2.94  veryGood
# 191      0  800  3.54      good
# 192      0  640  3.76      good
# 193      0  380  3.59        ok
# 194      1  600  3.47  veryGood
# 195      0  560  3.59  veryGood
# 196      0  660  3.07      good
# 197      1  400  3.23        ok
# 198      0  600  3.63      good
# 199      0  580  3.77        ok
# 200      0  800  3.31      good
# 201      1  580  3.20  veryGood
# 202      1  700  4.00      best
# 203      0  420  3.92        ok
# 204      1  600  3.89      best
# 205      1  780  3.80      good
# 206      0  740  3.54      best
# 207      1  640  3.63      best
# 208      0  540  3.16      good
# 209      0  580  3.50  veryGood
# 210      0  740  3.34        ok
# 211      0  580  3.02  veryGood
# 212      0  460  2.87  veryGood
# 213      0  640  3.38      good
# 214      1  600  3.56  veryGood
# 215      1  660  2.91      good
# 216      0  340  2.90      best
# 217      1  460  3.64      best
# 218      0  460  2.98      best
# 219      1  560  3.59  veryGood
# 220      0  540  3.28      good
# 221      0  680  3.99      good
# 222      1  480  3.02      best
# 223      0  800  3.47      good
# 224      0  800  2.90  veryGood
# 225      1  720  3.50      good
# 226      0  620  3.58  veryGood
# 227      0  540  3.02        ok
# 228      0  480  3.43  veryGood
# 229      1  720  3.42  veryGood
# 230      0  580  3.29        ok
# 231      0  600  3.28      good
# 232      0  380  3.38  veryGood
# 233      0  420  2.67      good
# 234      1  800  3.53      best
# 235      0  620  3.05  veryGood
# 236      1  660  3.49  veryGood
# 237      0  480  4.00  veryGood
# 238      0  500  2.86        ok
# 239      0  700  3.45      good
# 240      0  440  2.76  veryGood
# 241      1  520  3.81      best
# 242      1  680  2.96      good
# 243      0  620  3.22  veryGood
# 244      0  540  3.04      best
# 245      0  800  3.91      good
# 246      0  680  3.34  veryGood
# 247      0  440  3.17  veryGood
# 248      0  680  3.64      good
# 249      0  640  3.73      good
# 250      0  660  3.31        ok
# 251      0  620  3.21        ok
# 252      1  520  4.00  veryGood
# 253      1  540  3.55        ok
# 254      1  740  3.52        ok
# 255      0  640  3.35      good
# 256      1  520  3.30  veryGood
# 257      1  620  3.95      good
# 258      0  520  3.51  veryGood
# 259      0  640  3.81  veryGood
# 260      0  680  3.11  veryGood
# 261      0  440  3.15  veryGood
# 262      1  520  3.19      good
# 263      1  620  3.95      good
# 264      1  520  3.90      good
# 265      0  380  3.34      good
# 266      0  560  3.24        ok
# 267      1  600  3.64      good
# 268      1  680  3.46  veryGood
# 269      0  500  2.81      good
# 270      1  640  3.95  veryGood
# 271      0  540  3.33      good
# 272      1  680  3.67  veryGood
# 273      0  660  3.32      best
# 274      0  520  3.12  veryGood
# 275      1  600  2.98  veryGood
# 276      0  460  3.77      good
# 277      1  580  3.58      best
# 278      1  680  3.00        ok
# 279      1  660  3.14  veryGood
# 280      0  660  3.94  veryGood
# 281      0  360  3.27      good
# 282      0  660  3.45        ok
# 283      0  520  3.10        ok
# 284      1  440  3.39  veryGood
# 285      0  600  3.31        ok
# 286      1  800  3.22      best
# 287      1  660  3.70        ok
# 288      0  800  3.15        ok
# 289      0  420  2.26        ok
# 290      1  620  3.45  veryGood
# 291      0  800  2.78  veryGood
# 292      0  680  3.70  veryGood
# 293      0  800  3.97      best
# 294      0  480  2.55      best
# 295      0  520  3.25      good
# 296      0  560  3.16      best
# 297      0  460  3.07  veryGood
# 298      0  540  3.50  veryGood
# 299      0  720  3.40      good

# %%
dfTest.head()
# Out:
#    admit  gre   gpa prestige
# 0      0  380  3.61     good
# 1      1  660  3.67     good
# 2      1  800  4.00     best
# 3      1  640  3.19       ok
# 4      0  520  2.93       ok

# %%
print(dfTrain.describe())
# Out:
#             admit         gre         gpa
# count  300.000000  300.000000  300.000000
# mean     0.306667  590.866667    3.386233
# std      0.461880  117.717630    0.374880
# min      0.000000  300.000000    2.260000
# 25%      0.000000  515.000000    3.130000
# 50%      0.000000  600.000000    3.390000
# 75%      1.000000  680.000000    3.642500
# max      1.000000  800.000000    4.000000

# %%
print (dfTrain.std())
# Out:
# admit      0.46188
# gre      117.71763
# gpa        0.37488
# dtype: float64

# %%
dfTrain.groupby('admit').size()
# Out:
# admit
# 0    208
# 1     92
# dtype: int64

# %%
dfTrain.groupby('prestige').size()
# Out:
# prestige
# best         45
# good         92
# ok           56
# veryGood    107
# dtype: int64

# %%
dfTrain.groupby('admit').mean()
# Out:
#               gre       gpa
# admit
# 0      573.461538  3.336587
# 1      630.217391  3.498478

# %%
dfTrain.groupby('prestige').mean()
# Out:
#              admit         gre       gpa
# prestige
# best      0.555556  620.444444  3.480889
# good      0.206522  579.130435  3.449457
# ok        0.160714  573.571429  3.298571
# veryGood  0.364486  597.570093  3.337944

# %%
dfTrain.groupby('prestige').mean()[['gre','gpa']]
# Out:
#                  gre       gpa
# prestige
# best      620.444444  3.480889
# good      579.130435  3.449457
# ok        573.571429  3.298571
# veryGood  597.570093  3.337944

# %%
list(dfTrain.groupby('admit')['prestige'])
# Out:
# [(0, 0          good
#   4            ok
#   7      veryGood
#   9      veryGood
#   10           ok
#   11         best
#   13     veryGood
#   15         good
#   16           ok
#   17         good
#   18     veryGood
#   20         good
#   22           ok
#   23           ok
#   29         best
#   30           ok
#   31         good
#   32         good
#   34         best
#   35     veryGood
#   36         best
#   37         good
#   40     veryGood
#   43         good
#   44     veryGood
#   47           ok
#   48           ok
#   49         good
#   50         good
#   51           ok
#   52           ok
#   54         good
#   56         good
#   57         good
#   58     veryGood
#   59           ok
#   61           ok
#   62         good
#   64         good
#   65     veryGood
#   66           ok
#   67         best
#   68         best
#   69         best
#   70         good
#   71           ok
#   72           ok
#   73     veryGood
#   74           ok
#   75         good
#   76         good
#   78         best
#   80           ok
#   81     veryGood
#   82     veryGood
#   83           ok
#   85     veryGood
#   86     veryGood
#   87     veryGood
#   88         best
#   90     veryGood
#   92     veryGood
#   93     veryGood
#   95     veryGood
#   96           ok
#   97     veryGood
#   98     veryGood
#   99         good
#   100        good
#   101        good
#   102          ok
#   103        good
#   107    veryGood
#   108        good
#   109    veryGood
#   110          ok
#   111          ok
#   112        good
#   113        best
#   114        good
#   115        good
#   117    veryGood
#   119        good
#   122        good
#   123        good
#   124        good
#   125          ok
#   127          ok
#   128    veryGood
#   129          ok
#   131    veryGood
#   132    veryGood
#   133        good
#   134    veryGood
#   135        good
#   136          ok
#   137        good
#   138    veryGood
#   140    veryGood
#   142          ok
#   143        good
#   144          ok
#   145        good
#   146    veryGood
#   147        good
#   149        best
#   151    veryGood
#   153        good
#   154        good
#   156    veryGood
#   158    veryGood
#   159        good
#   160    veryGood
#   161    veryGood
#   163    veryGood
#   164    veryGood
#   165        best
#   166          ok
#   167        good
#   168        good
#   169        good
#   170        good
#   171        good
#   172        good
#   174          ok
#   176    veryGood
#   178        good
#   179        good
#   180        good
#   181          ok
#   182    veryGood
#   184          ok
#   185    veryGood
#   186        good
#   187    veryGood
#   188    veryGood
#   189    veryGood
#   191        good
#   192        good
#   193          ok
#   195    veryGood
#   196        good
#   198        good
#   199          ok
#   200        good
#   203          ok
#   206        best
#   208        good
#   209    veryGood
#   210          ok
#   211    veryGood
#   212    veryGood
#   213        good
#   216        best
#   218        best
#   220        good
#   221        good
#   223        good
#   224    veryGood
#   226    veryGood
#   227          ok
#   228    veryGood
#   230          ok
#   231        good
#   232    veryGood
#   233        good
#   235    veryGood
#   237    veryGood
#   238          ok
#   239        good
#   240    veryGood
#   243    veryGood
#   244        best
#   245        good
#   246    veryGood
#   247    veryGood
#   248        good
#   249        good
#   250          ok
#   251          ok
#   255        good
#   258    veryGood
#   259    veryGood
#   260    veryGood
#   261    veryGood
#   265        good
#   266          ok
#   269        good
#   271        good
#   273        best
#   274    veryGood
#   276        good
#   280    veryGood
#   281        good
#   282          ok
#   283          ok
#   285          ok
#   288          ok
#   289          ok
#   291    veryGood
#   292    veryGood
#   293        best
#   294        best
#   295        good
#   296        best
#   297    veryGood
#   298    veryGood
#   299        good
#   Name: prestige, dtype: object), (1, 1          good
#   2          best
#   3            ok
#   5      veryGood
#   6          best
#   8          good
#   12         best
#   14         best
#   19         best
#   21     veryGood
#   24     veryGood
#   25         best
#   26         best
#   27           ok
#   28     veryGood
#   33         good
#   38     veryGood
#   39         good
#   41     veryGood
#   42     veryGood
#   45         good
#   46     veryGood
#   53     veryGood
#   55         good
#   60     veryGood
#   63         good
#   77         good
#   79         best
#   84         good
#   89     veryGood
#   91         best
#   94     veryGood
#   104    veryGood
#   105    veryGood
#   106        best
#   116    veryGood
#   118        best
#   120    veryGood
#   121    veryGood
#   126        best
#   130    veryGood
#   139        best
#   141          ok
#   148        best
#   150        best
#   152    veryGood
#   155          ok
#   157        best
#   162    veryGood
#   173    veryGood
#   175    veryGood
#   177        good
#   183    veryGood
#   190    veryGood
#   194    veryGood
#   197          ok
#   201    veryGood
#   202        best
#   204        best
#   205        good
#   207        best
#   214    veryGood
#   215        good
#   217        best
#   219    veryGood
#   222        best
#   225        good
#   229    veryGood
#   234        best
#   236    veryGood
#   241        best
#   242        good
#   252    veryGood
#   253          ok
#   254          ok
#   256    veryGood
#   257        good
#   262        good
#   263        good
#   264        good
#   267        good
#   268    veryGood
#   270    veryGood
#   272    veryGood
#   275    veryGood
#   277        best
#   278          ok
#   279    veryGood
#   284    veryGood
#   286        best
#   287          ok
#   290    veryGood
#   Name: prestige, dtype: object)]

# %%
print(pd.crosstab(dfTrain['admit'], dfTrain['prestige']))
# Out:
# prestige  best  good  ok  veryGood
# admit
# 0           20    73  47        68
# 1           25    19   9        39

# %%
pd.crosstab(dfTrain['admit'], dfTrain['prestige'], rownames=['Admit']).loc[1].sum()
# Out:
# 92

# %%
pd.crosstab(dfTrain['admit'], dfTrain['prestige'], rownames=['Admit']).loc[0].sum()
# Out:
# 208

# %%
print(pd.crosstab(dfTrain['admit'], dfTrain['prestige'], rownames=['admit']).sum())
# Out:
# prestige
# best         45
# good         92
# ok           56
# veryGood    107
# dtype: int64

# %%
pd.crosstab(dfTrain['admit'], dfTrain['prestige'], rownames=['admit']).unstack()
# Out:
# prestige  admit
# best      0        20
#           1        25
# good      0        73
#           1        19
# ok        0        47
#           1         9
# veryGood  0        68
#           1        39
# dtype: int64

# %%
pd.crosstab(dfTrain['admit'], dfTrain['prestige'], rownames=['admit']).unstack().plot(kind='bar')

# %%
pd.crosstab(dfTrain['admit'], dfTrain['prestige'], rownames=['Admit']).plot(kind='bar')

# %%
pd.crosstab(dfTrain['admit'], dfTrain['prestige'], rownames=['Admit']).plot(kind='box',figsize=(15,11))

# %%
print(pd.crosstab(dfTrain['prestige'], dfTrain['admit'], rownames=['prestige']))
# Out:
# admit      0   1
# prestige
# best      20  25
# good      73  19
# ok        47   9
# veryGood  68  39

# %%
print(pd.crosstab(dfTrain['prestige'], dfTrain['admit'], rownames=['prestige']).unstack())
# Out:
# admit  prestige
# 0      best        20
#        good        73
#        ok          47
#        veryGood    68
# 1      best        25
#        good        19
#        ok           9
#        veryGood    39
# dtype: int64

# %%
pd.crosstab(dfTrain['prestige'], dfTrain['admit'], rownames=['prestige']).unstack().plot(kind='bar')

# %%
pd.crosstab(dfTrain['prestige'], dfTrain['admit'], rownames=['rowname']).plot(kind='bar')

# %%
s=dfTrain.pivot_table('gpa', index='admit', columns='prestige')
s
# Out:
# prestige    best      good        ok  veryGood
# admit
# 0         3.3005  3.420274  3.285319  3.292794
# 1         3.6252  3.561579  3.367778  3.416667

# %%
s.loc[1]
# Out:
# prestige
# best        3.625200
# good        3.561579
# ok          3.367778
# veryGood    3.416667
# Name: 1, dtype: float64

# %%
dfTrain.pivot_table('gre', index='admit', columns='prestige')
# Out:
# prestige   best        good          ok    veryGood
# admit
# 0         588.0  564.931507  567.234043  582.647059
# 1         646.4  633.684211  606.666667  623.589744

# %%
#dfTrain['gpa'].hist()
dfTrain['gre'].hist()

# %%
dfTrain['gpa'].hist()
#dfTrain['gre'].hist()

# %%
pd.crosstab(dfTrain.gre, dfTrain.admit.astype(bool)).plot(kind='bar')
pl.title('GRE score by Admission Status')
pl.xlabel('GRE score')
pl.ylabel('Frequency')
pl.show()

# %%
pd.crosstab(dfTrain.gre, dfTrain.admit.astype(bool)).plot(kind='hist')
pl.title('GRE score by Admission Status')
pl.xlabel('GRE score')
pl.ylabel('Frequency')
pl.show()

# %%
pd.crosstab(dfTrain.gpa, dfTrain.admit.astype(bool)).plot(kind='bar')
pl.title('GPA score by Admission Status')
pl.xlabel('GPA score')
pl.ylabel('Frequency')
pl.show()

# %%
pd.crosstab(dfTrain.gpa, dfTrain.admit.astype(bool)).plot(kind='hist')
pl.title('GPA score by Admission Status')
pl.xlabel('GPA score')
pl.ylabel('Frequency')
pl.show()

# %%
dummy_ranks = pd.get_dummies(dfTrain['prestige'], prefix='prestige')
print (dummy_ranks.head())
# Out:
#    prestige_best  prestige_good  prestige_ok  prestige_veryGood
# 0              0              1            0                  0
# 1              0              1            0                  0
# 2              1              0            0                  0
# 3              0              0            1                  0
# 4              0              0            1                  0

# %%
cols_to_keep = ['admit', 'gre', 'gpa']
data = dfTrain[cols_to_keep].join(dummy_ranks.loc[:, 'prestige_good':])
print (data.head())
# Out:
#    admit  gre   gpa  prestige_good  prestige_ok  prestige_veryGood
# 0      0  380  3.61              1            0                  0
# 1      1  660  3.67              1            0                  0
# 2      1  800  4.00              0            0                  0
# 3      1  640  3.19              0            1                  0
# 4      0  520  2.93              0            1                  0

# %%
data['intercept'] = 1.0

print (data.head())

train_cols = data.columns[1:]
print (data.columns[1:])
# Out:
#    admit  gre   gpa  prestige_good  prestige_ok  prestige_veryGood  intercept
# 0      0  380  3.61              1            0                  0        1.0
# 1      1  660  3.67              1            0                  0        1.0
# 2      1  800  4.00              0            0                  0        1.0
# 3      1  640  3.19              0            1                  0        1.0
# 4      0  520  2.93              0            1                  0        1.0
# Index(['gre', 'gpa', 'prestige_good', 'prestige_ok', 'prestige_veryGood',
#        'intercept'],
#       dtype='object')

# %%
#Logistic Regression
logit = sm.Logit(data['admit'], data[train_cols])

# fit the model
result = logit.fit()
print (result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.546708
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  admit   No. Observations:                  300
# Model:                          Logit   Df Residuals:                      294
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 20 May 2020   Pseudo R-squ.:                  0.1131
# Time:                        21:07:17   Log-Likelihood:                -164.01
# converged:                       True   LL-Null:                       -184.92
# Covariance Type:            nonrobust   LLR p-value:                 6.406e-08
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# gre                   0.0030      0.001      2.346      0.019       0.000       0.006
# gpa                   0.9316      0.406      2.294      0.022       0.136       1.728
# prestige_good        -1.5434      0.413     -3.740      0.000      -2.352      -0.735
# prestige_ok          -1.6848      0.487     -3.457      0.001      -2.640      -0.730
# prestige_veryGood    -0.6248      0.378     -1.654      0.098      -1.365       0.116
# intercept            -4.8787      1.416     -3.445      0.001      -7.655      -2.103
# =====================================================================================

# %%
dfTrain
# Out:
#      admit  gre   gpa  prestige
# 0        0  380  3.61      good
# 1        1  660  3.67      good
# 2        1  800  4.00      best
# 3        1  640  3.19        ok
# 4        0  520  2.93        ok
# ..     ...  ...   ...       ...
# 295      0  520  3.25      good
# 296      0  560  3.16      best
# 297      0  460  3.07  veryGood
# 298      0  540  3.50  veryGood
# 299      0  720  3.40      good
#
# [300 rows x 4 columns]

# %%
dfTrain.shape
# Out:
# (300, 4)

# %% [markdown]
# dfTrain.corr(method='pearson')

# %%
dfTrain.corr(method='pearson')
# Out:
#           admit       gre       gpa
# admit  1.000000  0.222689  0.199463
# gre    0.222689  1.000000  0.377243
# gpa    0.199463  0.377243  1.000000

# %%
dfTrain.dtypes
# Out:
# admit         int64
# gre           int64
# gpa         float64
# prestige     object
# dtype: object

# %%
dfTrain.skew()
# Out:
# admit    0.842776
# gre     -0.118480
# gpa     -0.189184
# dtype: float64

# %%
dfTrain.hist(figsize=(15,17))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E390A322C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E38FDCA908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E38FEAE888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E390A9A248>]],
#       dtype=object)

# %%
# KNN Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

# %%
array = dfTrain.values
X = array[:,1:3]
Y = array[:,0]
num_folds = 10
kfold = KFold(n_splits=10, random_state=7)
model = KNeighborsClassifier()
print(model.fit(X,Y))
z = array[0:1:,0:,1]
print(model.predict(X))
print(model.predict(z))
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
print(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-206-f010baa93da6> in <module>
#       5 kfold = KFold(n_splits=10, random_state=7)
#       6 model = KNeighborsClassifier()
# ----> 7 print(model.fit(X,Y))
#       8 z = array[0:1:,0:,1]
#       9 print(model.predict(X))
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     904             self.outputs_2d_ = True
#     905
# --> 906         check_classification_targets(y)
#     907         self.classes_ = []
#     908         self._y = np.empty(y.shape, dtype=np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     167     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     168                       'multilabel-indicator', 'multilabel-sequences']:
# --> 169         raise ValueError("Unknown label type: %r" % y_type)
#     170
#     171
#
# ValueError: Unknown label type: 'unknown'
