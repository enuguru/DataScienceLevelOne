# %%
import matplotlib.pyplot as plt
from numpy import set_printoptions
from pandas import read_csv
import pandas as pd

# %%
#filename = 'food_production.csv'
#names = ['Date','Centre_Name','Commodity_Name','Price']
data = pd.read_csv('food_production.csv', encoding='latin-1')

# %%
print(data)
# Out:
#       Area Abbreviation  Area Code         Area  Item Code  \
# 0                   AFG          2  Afghanistan       2511
# 1                   AFG          2  Afghanistan       2805
# 2                   AFG          2  Afghanistan       2513
# 3                   AFG          2  Afghanistan       2513
# 4                   AFG          2  Afghanistan       2514
# ...                 ...        ...          ...        ...
# 21472               ZWE        181     Zimbabwe       2948
# 21473               ZWE        181     Zimbabwe       2960
# 21474               ZWE        181     Zimbabwe       2960
# 21475               ZWE        181     Zimbabwe       2961
# 21476               ZWE        181     Zimbabwe       2928
#
#                            Item  Element Code Element         Unit  latitude  \
# 0            Wheat and products          5142    Food  1000 tonnes     33.94
# 1      Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# ...

# %%
print(data.shape)
# Out:
# (21477, 63)

# %%
print(data.dtypes)
# Out:
# Area Abbreviation     object
# Area Code              int64
# Area                  object
# Item Code              int64
# Item                  object
#                       ...
# Y2009                float64
# Y2010                float64
# Y2011                float64
# Y2012                  int64
# Y2013                  int64
# Length: 63, dtype: object

# %%
data.ndim
# Out:
# 2

# %%
print(data.head())
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2511
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2513
# 3               AFG          2  Afghanistan       2513
# 4               AFG          2  Afghanistan       2514
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# 3       Barley and products          5142    Food  1000 tonnes     33.94
# 4        Maize and products          5521    Feed  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# ...

# %%
print(data.head(10))
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2511
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2513
# 3               AFG          2  Afghanistan       2513
# 4               AFG          2  Afghanistan       2514
# 5               AFG          2  Afghanistan       2514
# 6               AFG          2  Afghanistan       2517
# 7               AFG          2  Afghanistan       2520
# 8               AFG          2  Afghanistan       2531
# 9               AFG          2  Afghanistan       2536
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# ...

# %%
print(data.tail())
# Out:
#       Area Abbreviation  Area Code      Area  Item Code  \
# 21472               ZWE        181  Zimbabwe       2948
# 21473               ZWE        181  Zimbabwe       2960
# 21474               ZWE        181  Zimbabwe       2960
# 21475               ZWE        181  Zimbabwe       2961
# 21476               ZWE        181  Zimbabwe       2928
#
#                           Item  Element Code Element         Unit  latitude  \
# 21472  Milk - Excluding Butter          5142    Food  1000 tonnes    -19.02
# 21473            Fish, Seafood          5521    Feed  1000 tonnes    -19.02
# 21474            Fish, Seafood          5142    Food  1000 tonnes    -19.02
# 21475  Aquatic Products, Other          5142    Food  1000 tonnes    -19.02
# 21476            Miscellaneous          5142    Food  1000 tonnes    -19.02
#
#        longitude  ...  Y2004  Y2005  Y2006  Y2007  Y2008  Y2009  Y2010  Y2011  \
# 21472      29.15  ...  373.0  357.0  359.0  356.0  341.0  385.0  418.0  457.0
# ...

# %%
print(data.tail(10))
# Out:
#       Area Abbreviation  Area Code      Area  Item Code  \
# 21467               ZWE        181  Zimbabwe       2943
# 21468               ZWE        181  Zimbabwe       2945
# 21469               ZWE        181  Zimbabwe       2946
# 21470               ZWE        181  Zimbabwe       2949
# 21471               ZWE        181  Zimbabwe       2948
# 21472               ZWE        181  Zimbabwe       2948
# 21473               ZWE        181  Zimbabwe       2960
# 21474               ZWE        181  Zimbabwe       2960
# 21475               ZWE        181  Zimbabwe       2961
# 21476               ZWE        181  Zimbabwe       2928
#
#                           Item  Element Code Element         Unit  latitude  \
# 21467                     Meat          5142    Food  1000 tonnes    -19.02
# 21468                   Offals          5142    Food  1000 tonnes    -19.02
# 21469              Animal fats          5142    Food  1000 tonnes    -19.02
# ...

# %%
print(data['Item'])
# Out:
# 0              Wheat and products
# 1        Rice (Milled Equivalent)
# 2             Barley and products
# 3             Barley and products
# 4              Maize and products
#                    ...
# 21472     Milk - Excluding Butter
# 21473               Fish, Seafood
# 21474               Fish, Seafood
# 21475     Aquatic Products, Other
# 21476               Miscellaneous
# Name: Item, Length: 21477, dtype: object

# %%
data.drop(['Item'],axis=1)
# Out:
#       Area Abbreviation  Area Code         Area  Item Code  Element Code  \
# 0                   AFG          2  Afghanistan       2511          5142
# 1                   AFG          2  Afghanistan       2805          5142
# 2                   AFG          2  Afghanistan       2513          5521
# 3                   AFG          2  Afghanistan       2513          5142
# 4                   AFG          2  Afghanistan       2514          5521
# ...                 ...        ...          ...        ...           ...
# 21472               ZWE        181     Zimbabwe       2948          5142
# 21473               ZWE        181     Zimbabwe       2960          5521
# 21474               ZWE        181     Zimbabwe       2960          5142
# 21475               ZWE        181     Zimbabwe       2961          5142
# 21476               ZWE        181     Zimbabwe       2928          5142
#
#       Element         Unit  latitude  longitude   Y1961  ...   Y2004   Y2005  \
# ...

# %%
print(data[['Area','Item', 'Y2013']]) #print(data['Date', 'Commodity_Name'])
# Out:
#               Area                      Item  Y2013
# 0      Afghanistan        Wheat and products   4895
# 1      Afghanistan  Rice (Milled Equivalent)    422
# 2      Afghanistan       Barley and products    360
# 3      Afghanistan       Barley and products     89
# 4      Afghanistan        Maize and products    200
# ...            ...                       ...    ...
# 21472     Zimbabwe   Milk - Excluding Butter    451
# 21473     Zimbabwe             Fish, Seafood     15
# 21474     Zimbabwe             Fish, Seafood     40
# 21475     Zimbabwe   Aquatic Products, Other      0
# 21476     Zimbabwe             Miscellaneous      0
#
# [21477 rows x 3 columns]

# %%
data.drop(columns=['Area', 'Item'])
# Out:
#       Area Abbreviation  Area Code  Item Code  Element Code Element  \
# 0                   AFG          2       2511          5142    Food
# 1                   AFG          2       2805          5142    Food
# 2                   AFG          2       2513          5521    Feed
# 3                   AFG          2       2513          5142    Food
# 4                   AFG          2       2514          5521    Feed
# ...                 ...        ...        ...           ...     ...
# 21472               ZWE        181       2948          5142    Food
# 21473               ZWE        181       2960          5521    Feed
# 21474               ZWE        181       2960          5142    Food
# 21475               ZWE        181       2961          5142    Food
# 21476               ZWE        181       2928          5142    Food
#
#               Unit  latitude  longitude   Y1961   Y1962  ...   Y2004   Y2005  \
# ...

# %%
#data.rename(columns={"Date": "Date_of_Sale"})

# %%
#data = data.rename(columns={"Date_of_Sale": "Date"})
data
# Out:
#       Area Abbreviation  Area Code         Area  Item Code  \
# 0                   AFG          2  Afghanistan       2511
# 1                   AFG          2  Afghanistan       2805
# 2                   AFG          2  Afghanistan       2513
# 3                   AFG          2  Afghanistan       2513
# 4                   AFG          2  Afghanistan       2514
# ...                 ...        ...          ...        ...
# 21472               ZWE        181     Zimbabwe       2948
# 21473               ZWE        181     Zimbabwe       2960
# 21474               ZWE        181     Zimbabwe       2960
# 21475               ZWE        181     Zimbabwe       2961
# 21476               ZWE        181     Zimbabwe       2928
#
#                            Item  Element Code Element         Unit  latitude  \
# 0            Wheat and products          5142    Food  1000 tonnes     33.94
# 1      Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# ...

# %%
# Single selections using iloc and DataFrame

# Rows:

data.iloc[0] # first row of data frame
# Out:
# Area Abbreviation                   AFG
# Area Code                             2
# Area                        Afghanistan
# Item Code                          2511
# Item                 Wheat and products
#                             ...
# Y2009                              4538
# Y2010                              4605
# Y2011                              4711
# Y2012                              4810
# Y2013                              4895
# Name: 0, Length: 63, dtype: object

# %%
data.iloc[1] # second row of data frame
# Out:
# Area Abbreviation                         AFG
# Area Code                                   2
# Area                              Afghanistan
# Item Code                                2805
# Item                 Rice (Milled Equivalent)
#                                ...
# Y2009                                     415
# Y2010                                     442
# Y2011                                     476
# Y2012                                     425
# Y2013                                     422
# Name: 1, Length: 63, dtype: object

# %%
data.iloc[-1] # last row of data frame
# Out:
# Area Abbreviation              ZWE
# Area Code                      181
# Area                      Zimbabwe
# Item Code                     2928
# Item                 Miscellaneous
#                          ...
# Y2009                            0
# Y2010                            0
# Y2011                            0
# Y2012                            0
# Y2013                            0
# Name: 21476, Length: 63, dtype: object

# %%
data.iloc[:,0] # first column of data frame
# Out:
# 0        AFG
# 1        AFG
# 2        AFG
# 3        AFG
# 4        AFG
#         ...
# 21472    ZWE
# 21473    ZWE
# 21474    ZWE
# 21475    ZWE
# 21476    ZWE
# Name: Area Abbreviation, Length: 21477, dtype: object

# %%
data.iloc[:,1] # second column of data frame
# Out:
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
#         ...
# 21472    181
# 21473    181
# 21474    181
# 21475    181
# 21476    181
# Name: Area Code, Length: 21477, dtype: int64

# %%
data.iloc[:,-1] # last column of data frame and all rows
# Out:
# 0        4895
# 1         422
# 2         360
# 3          89
# 4         200
#          ...
# 21472     451
# 21473      15
# 21474      40
# 21475       0
# 21476       0
# Name: Y2013, Length: 21477, dtype: int64

# %%
print(data.iloc[0:5]) # first five rows of dataframe

print(data.iloc[:, 0:2]) # first two columns of data frame with all rows
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2511
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2513
# 3               AFG          2  Afghanistan       2513
# 4               AFG          2  Afghanistan       2514
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# 3       Barley and products          5142    Food  1000 tonnes     33.94
# 4        Maize and products          5521    Feed  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# ...

# %%
print(data.iloc[[0,3,6,24], [0,2,3]])

print(data.iloc[0:5, 2:4])
# Out:
#    Area Abbreviation         Area  Item Code
# 0                AFG  Afghanistan       2511
# 3                AFG  Afghanistan       2513
# 6                AFG  Afghanistan       2517
# 24               AFG  Afghanistan       2575
#           Area  Item Code
# 0  Afghanistan       2511
# 1  Afghanistan       2805
# 2  Afghanistan       2513
# 3  Afghanistan       2513
# 4  Afghanistan       2514

# %%
data.set_index("Area", inplace=True)

data
# Out:
#             Area Abbreviation  Area Code  Item Code                      Item  \
# Area
# Afghanistan               AFG          2       2511        Wheat and products
# Afghanistan               AFG          2       2805  Rice (Milled Equivalent)
# Afghanistan               AFG          2       2513       Barley and products
# Afghanistan               AFG          2       2513       Barley and products
# Afghanistan               AFG          2       2514        Maize and products
# ...                       ...        ...        ...                       ...
# Zimbabwe                  ZWE        181       2948   Milk - Excluding Butter
# Zimbabwe                  ZWE        181       2960             Fish, Seafood
# Zimbabwe                  ZWE        181       2960             Fish, Seafood
# Zimbabwe                  ZWE        181       2961   Aquatic Products, Other
# Zimbabwe                  ZWE        181       2928             Miscellaneous
#
# ...

# %%
data.reset_index("Area", inplace=True)

# %%
data
# Out:
#               Area Area Abbreviation  Area Code  Item Code  \
# 0      Afghanistan               AFG          2       2511
# 1      Afghanistan               AFG          2       2805
# 2      Afghanistan               AFG          2       2513
# 3      Afghanistan               AFG          2       2513
# 4      Afghanistan               AFG          2       2514
# ...            ...               ...        ...        ...
# 21472     Zimbabwe               ZWE        181       2948
# 21473     Zimbabwe               ZWE        181       2960
# 21474     Zimbabwe               ZWE        181       2960
# 21475     Zimbabwe               ZWE        181       2961
# 21476     Zimbabwe               ZWE        181       2928
#
#                            Item  Element Code Element         Unit  latitude  \
# 0            Wheat and products          5142    Food  1000 tonnes     33.94
# 1      Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# ...

# %%
data['Y2013']
