# %%
import pandas as pd
import csv

# %%
fields = ['Name','Age','Address','Qualification']
data=pd.read_csv('some.csv',names=fields)

# %%
data
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd

# %%
data[['Name','Age']].to_csv("newfile.csv")

# %%
df=data[['Name','Age']]

# %%
df
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24
# 2  Gaurav   22
# 3    Anuj   32

# %%
fields = ['Sno','Date','Time','State/UnionTerritory','ConfirmedIndianNational','ConfirmedForeignNational','Cured','Deaths','Confirmed']
# name of csv file 
filename = "covid_19_india.csv"

# %%
data=pd.read_csv('covid_19_india.csv',names=fields)

# %%
data
# Out:
#            Sno     Date                                      Time  \
# Sno       Date     Time                      State/UnionTerritory
# 1     30/01/20  6:00 PM                                    Kerala
# 2     31/01/20  6:00 PM                                    Kerala
# 3     01/02/20  6:00 PM                                    Kerala
# 4     02/02/20  6:00 PM                                    Kerala
# 5     03/02/20  6:00 PM                                    Kerala
# 6     04/02/20  6:00 PM                                    Kerala
# 7     05/02/20  6:00 PM                                    Kerala
# 8     06/02/20  6:00 PM                                    Kerala
# 9     07/02/20  6:00 PM                                    Kerala
# 10    08/02/20  6:00 PM                                    Kerala
# 11    09/02/20  6:00 PM                                    Kerala
# 12    10/02/20  6:00 PM                                    Kerala
# ...

# %%
import csv
with open('large.csv','w') as f1:
    writer=csv.writer(f1, delimiter=',',lineterminator='\n',)
    f = open('covid_19_india.csv')
    csv_f = csv.reader(f)
    for row in csv_f:
        #print(row[0],row[1],row[2],row[3],row[4],row[5],row[6],row[7],row[8])
        writer.writerow(row)
