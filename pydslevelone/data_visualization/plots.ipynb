# %% [markdown]
# # import modules

# %%
# %matplotlib inline
import numpy
from pandas import read_csv
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show
import pandas as pd
from pandas.plotting import scatter_matrix

# %% [markdown]
# # read csv

# %%
filename = "pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
pima = read_csv(filename, names=names)
pima
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %% [markdown]
# # plot the density plot

# %%
pima.plot(kind='density', subplots=True, figsize= (11,13),layout=(3,3),sharex=False,sharey=False)
plt.show()

# %%
pima.groupby(by='class').size()
# Out:
# class
# 0    500
# 1    268
# dtype: int64

# %%
pima.loc[:,'class'].sum()
# Out:
# 268

# %%
len(pima[(pima.age > 30) & (pima.age < 40)])
# Out:
# 144

# %%
pima[(pima.age > 30) & (pima.age < 40)].groupby('class').size()
# Out:
# class
# 0    74
# 1    70
# dtype: int64

# %%
len(pima[pima["age"].between(20,51)])
# Out:
# 695

# %%
pima.describe()
# Out:
#              preg        plas        pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %% [markdown]
# # box plot or box and whisker plot

# %%
pima[pima["age"].between(20,51)].plot(kind='box', subplots=True, figsize=(15,17),layout=(3,3), sharex=False, sharey=False)
plt.show()

# %%
pima.plot(kind='box', subplots=True, figsize=(15,17),layout=(3,3), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# # histogram plot

# %%
pima.hist(figsize=(11,11))
plt.show()

# %% [markdown]
# # scatter matrix plot

# %%
#url = "pima-indians-diabetes.csv"
#names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
#data = pd.read_csv(url, names=names)
scatter_matrix(pima, figsize=(14,9))
plt.show()

# %%
pima.corr()
# Out:
#            preg      plas      pres      skin      test      mass      pedi  \
# preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# preg   0.544341  0.221898
# plas   0.263514  0.466581
# pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %%
correlations = pima.corr()
# plot correlation matrix
fig = plt.figure(figsize=(14,9))
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
plt.show()

# %%
correlations = pima.corr()
# plot correlation matrix
fig = plt.figure(figsize=(14,9))
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()

# %%
fruits = ['apples', 'pears', 'cherries', 'bananas']
series = pd.Series([20, 30, 40, 10], 
                   index=fruits, 
                   name='series')

series.plot.pie(figsize=(6, 6))
# Out:
# <Axes: ylabel='series'>

# %%
fruits = ['apples', 'pears', 'cherries', 'bananas']

series = pd.Series([20, 30, 40, 10], 
                   index=fruits, 
                   name='series')
explode = [0.10, 0.20, 0.30, 0.9]
series.plot.pie(figsize=(9, 9), explode=explode)
# Out:
# <Axes: ylabel='series'>

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy
import pandas as pd                #for handling datasets
import statsmodels.api as sm       #for statistical modeling
import pylab as pl                 #for plotting
import numpy as np                 #for numerical computation

# %%
dfTrain = pd.read_csv("train_university_admission_data.csv")
dfTest = pd.read_csv("test_university_admission_data.csv")

# %%
dfTrain

# %%
dfTrain.hist(figsize=(11,9))

# %%
dfTrain['gpa'].hist(figsize=(17,8))

# %%
dfTrain['gre'].hist(figsize=(17,8))

# %%
pd.crosstab(dfTrain.gre, dfTrain.prestige).plot(kind='bar',figsize=(19,9))
pl.title('GRE score by Admission Status')
pl.xlabel('GRE score')
pl.ylabel('Frequency')
pl.show()

# %%
pd.crosstab(dfTrain.gpa, dfTrain.admit.astype(bool)).plot(kind='bar',figsize=(19,9))
pl.title('GPA score by Admission Status')
pl.xlabel('GPA score')
pl.ylabel('Frequency')
pl.show()
